# %%
from scipy.io import arff
import pandas as pd

data = arff.loadarff('Z:\code\data.arff')
df = pd.DataFrame(data[0])

df.head()
# Out:
#      ge      cst      tnp      twp    iap      esp   arr            ms    ls  \
# 0  b'F'     b'G'  b'Good'  b'Good'  b'Vg'  b'Good'  b'Y'  b'Unmarried'  b'V'
# 1  b'M'   b'OBC'    b'Vg'    b'Vg'  b'Vg'    b'Vg'  b'N'  b'Unmarried'  b'V'
# 2  b'F'   b'OBC'  b'Good'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
# 3  b'M'  b'MOBC'  b'Pass'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
# 4  b'M'     b'G'  b'Good'  b'Good'  b'Vg'    b'Vg'  b'N'  b'Unmarried'  b'V'
#
#         as        fmi          fs     fq     mq           fo            mo  \
# 0  b'Paid'  b'Medium'  b'Average'  b'Um'  b'10'    b'Farmer'  b'Housewife'
# 1  b'Paid'     b'Low'  b'Average'  b'Um'  b'Il'   b'Service'    b'Service'
# 2  b'Paid'      b'Am'  b'Average'  b'12'  b'10'   b'Service'  b'Housewife'
# 3  b'Paid'  b'Medium'    b'Small'  b'12'  b'Um'  b'Business'   b'Business'
# 4  b'Paid'      b'Am'  b'Average'  b'10'  b'12'   b'Service'  b'Housewife'
#
# ...

# %%
import os
import pandas as pd
data = pd.read_csv("Z:\code\data.csv")

# %%
data
# Out:
#     ge   cst   tnp   twp   iap   esp arr         ms ls    as     fmi       fs  \
# 0    F     G  Good  Good    Vg  Good   Y  Unmarried  V  Paid  Medium  Average
# 1    M   OBC    Vg    Vg    Vg    Vg   N  Unmarried  V  Paid     Low  Average
# 2    F   OBC  Good  Good    Vg  Good   N  Unmarried  V  Paid      Am  Average
# 3    M  MOBC  Pass  Good    Vg  Good   N  Unmarried  V  Paid  Medium    Small
# 4    M     G  Good  Good    Vg    Vg   N  Unmarried  V  Paid      Am  Average
# 5    M   OBC    Vg  Good    Vg    Vg   N  Unmarried  V  Paid  Medium  Average
# 6    F   OBC  Good    Vg  Good  Good   N  Unmarried  V  Paid    High  Average
# 7    F   OBC  Good  Good  Good  Good   N  Unmarried  V  Paid  Medium    Small
# 8    F  MOBC    Vg  Good  Good    Vg   Y  Unmarried  V  Paid     Low    Small
# 9    F   OBC    Vg    Vg  Good    Vg   Y  Unmarried  V  Paid     Low    Small
# 10   M    ST    Vg    Vg  Good    Vg   N  Unmarried  V  Paid      Vh    Small
# ...

# %%
data.dtypes
# Out:
# ge     object
# cst    object
# tnp    object
# twp    object
# iap    object
# esp    object
# arr    object
# ms     object
# ls     object
# as     object
# fmi    object
# fs     object
# fq     object
# mq     object
# fo     object
# mo     object
# nf     object
# sh     object
# ss     object
# me     object
# tt     object
# atd    object
# dtype: object

# %%
data.shape
# Out:
# (131, 22)

# %%
data.ndim
# Out:
# 2

# %%
data.describe()
# Out:
#          ge  cst   tnp   twp  iap   esp  arr         ms   ls    as     fmi  \
# count   131  131   131   131  131   131  131        131  131   131     131
# unique    2    5     4     4    4     4    2          1    2     2       5
# top       M  OBC  Good  Good   Vg  Good    N  Unmarried    V  Paid  Medium
# freq     72   57    59    65   63    54   78        131   92    76      63
#
#            fs   fq   mq       fo         mo     nf       sh    ss   me     tt  \
# count     131  131  131      131        131    131      131   131  131    131
# unique      3    6    6        5          5      3        3     2    4      3
# top     Small   Um   Um  Service  Housewife  Large  Average  Govt  Eng  Small
# freq       89   40   52       38        115     58       59    91   62     78
#
#          atd
# count    131
# unique     3
# top     Good
# freq      56

# %%
data.head(3)
# Out:
#   ge  cst   tnp   twp iap   esp arr         ms ls    as     fmi       fs  fq  \
# 0  F    G  Good  Good  Vg  Good   Y  Unmarried  V  Paid  Medium  Average  Um
# 1  M  OBC    Vg    Vg  Vg    Vg   N  Unmarried  V  Paid     Low  Average  Um
# 2  F  OBC  Good  Good  Vg  Good   N  Unmarried  V  Paid      Am  Average  12
#
#    mq       fo         mo       nf       sh    ss   me       tt      atd
# 0  10   Farmer  Housewife    Large     Poor  Govt  Asm    Small     Good
# 1  Il  Service    Service    Small     Poor  Govt  Asm  Average  Average
# 2  10  Service  Housewife  Average  Average  Govt  Asm    Large     Good

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 101    False
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# 108    False
# 109    False
# 110    False
# 111    False
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# 119    False
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# 130    False
# Length: 131, dtype: bool

# %%
 data['cst'].value_counts()
# Out:
# OBC     57
# G       44
# ST      20
# MOBC     6
# SC       4
# Name: cst, dtype: int64

# %%
 data['ge'].value_counts()
# Out:
# M    72
# F    59
# Name: ge, dtype: int64

# %%
 data['ms'].value_counts()
# Out:
# Unmarried    131
# Name: ms, dtype: int64

# %%
 data['fo'].value_counts()
# Out:
# Service     38
# Business    34
# Others      29
# Farmer      27
# Retired      3
# Name: fo, dtype: int64

# %%
top10 = data["cst"].value_counts()
top10.sort_values(ascending=False)
top10 = top10[:10]
top10.plot(kind="bar")

# %%
top10 = data["fo"].value_counts()
top10.sort_values(ascending=False)
top10 = top10[:10]
top10.plot(kind="bar")

# %%
data.count()
# Out:
# ge     131
# cst    131
# tnp    131
# twp    131
# iap    131
# esp    131
# arr    131
# ms     131
# ls     131
# as     131
# fmi    131
# fs     131
# fq     131
# mq     131
# fo     131
# mo     131
# nf     131
# sh     131
# ss     131
# me     131
# tt     131
# atd    131
# dtype: int64

# %%
data.tail()
# Out:
#     ge   cst   tnp   twp   iap   esp arr         ms ls    as     fmi       fs  \
# 126  M     G  Pass  Good  Good  Pass   Y  Unmarried  T  Free     Low    Small
# 127  M  MOBC    Vg    Vg  Good  Good   N  Unmarried  V  Free    High    Small
# 128  F   OBC  Good  Good    Vg  Good   N  Unmarried  V  Free      Am    Large
# 129  M    ST  Pass  Pass  Good  Pass   Y  Unmarried  V  Free     Low  Average
# 130  M     G  Pass  Good  Good  Pass   Y  Unmarried  V  Free  Medium    Small
#
#      fq  mq        fo         mo       nf       sh    ss   me     tt      atd
# 126  Um  Il   Service  Housewife    Small  Average  Govt  Asm  Small     Poor
# 127  10  Um    Farmer  Housewife  Average     Poor  Govt  Asm  Small  Average
# 128  Il  Il    Farmer  Housewife    Small  Average  Govt  Asm  Large     Good
# 129  Um  Um   Service  Housewife  Average  Average  Govt  Asm  Large  Average
# 130  Um  Um  Business  Housewife  Average  Average  Govt  Asm  Small  Average

# %%
len(data)
# Out:
# 131

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 22 columns):
# ge     131 non-null object
# cst    131 non-null object
# tnp    131 non-null object
# twp    131 non-null object
# iap    131 non-null object
# esp    131 non-null object
# arr    131 non-null object
# ms     131 non-null object
# ls     131 non-null object
# as     131 non-null object
# fmi    131 non-null object
# fs     131 non-null object
# fq     131 non-null object
# mq     131 non-null object
# fo     131 non-null object
# mo     131 non-null object
# nf     131 non-null object
# sh     131 non-null object
# ss     131 non-null object
# me     131 non-null object
# tt     131 non-null object
# atd    131 non-null object
# dtypes: object(22)
# memory usage: 22.6+ KB
