# %%
import pandas as pd
df = pd.read_csv('dataf.csv')
print(df.shape)
df.head(15)
# Out:
# (132, 22)
#    ge   cst   tnp   twp   iap   esp arrr         ms ls    as   ...         fq  \
# 0   F     G  Good  Good    Vg  Good    Y  Unmarried  V  Paid   ...         Um
# 1   M   OBC    Vg    Vg    Vg    Vg    N  Unmarried  V  Paid   ...         Um
# 2   F   OBC  Good  Good    Vg  Good    N  Unmarried  V  Paid   ...         12
# 3   M  MOBC  Pass  Good    Vg  Good    N  Unmarried  V  Paid   ...         12
# 4   M     G  Good  Good    Vg    Vg    N  Unmarried  V  Paid   ...         10
# 5   M   OBC    Vg  Good    Vg    Vg    N  Unmarried  V  Paid   ...         10
# 6   F   OBC  Good    Vg  Good  Good    N  Unmarried  V  Paid   ...         12
# 7   F   OBC  Good  Good  Good  Good    N  Unmarried  V  Paid   ...         Il
# 8   F  MOBC    Vg  Good  Good    Vg    Y  Unmarried  V  Paid   ...         12
# 9   F   OBC    Vg    Vg  Good    Vg    Y  Unmarried  V  Paid   ...     Degree
# 10  M    ST    Vg    Vg  Good    Vg    N  Unmarried  V  Paid   ...         Pg
# ...

# %% [markdown]
# This dataset describes about the particular individual details like gender, caste, occupation of father and mother, educational qualities, marital status etc. On viewing the dataset, we can analyse an individuals needed details which will be needed for any queries.

# %%
df.describe()
# Out:
#          ge  cst   tnp   twp  iap   esp arrr         ms   ls    as  ...    fq  \
# count   132  131   131   131  131   131  131        131  131   131  ...   131
# unique    3    5     4     4    4     4    2          1    2     2  ...     6
# top       M  OBC  Good  Good   Vg  Good    N  Unmarried    V  Paid  ...    Um
# freq     72   57    59    65   63    54   78        131   92    76  ...    40
#
#          mq       fo         mo     nf       sh    ss   me     tt   atd
# count   131      131        131    131      131   131  131    131   131
# unique    6        5          5      3        3     2    4      3     3
# top      Um  Service  Housewife  Large  Average  Govt  Eng  Small  Good
# freq     52       38        115     58       59    91   62     78    56
#
# [4 rows x 22 columns]

# %% [markdown]
# This tells about the count of entries and the top max entry in each column with its frequency.

# %%
import matplotlib.pyplot as plt
df.boxplot('cf')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-1fadb4a607ea> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 df.boxplot('cf')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2255     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2256                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2257                  return_type=return_type, **kwds)
#    2258     plt.draw_if_interactive()
#    2259     return ax
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2239             columns = data.columns
#    2240         else:
# ...
