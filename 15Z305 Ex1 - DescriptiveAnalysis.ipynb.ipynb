# %% [markdown]
# Importing the header files
# Reading the dataset

# %%
import pandas as pd
data=pd.read_csv('C:/Users/Akilan/Downloads/EmployeeAttrition.csv')
data.head()

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# We can infer that the min age is 18 and where does most of the age lies and average of ages.

# %%
 data.boxplot('Age',by='Attrition')
graphdata=data.groupby(['JobRole','Attrition']).size()
graphdata
# Out:
# JobRole                    Attrition
# Healthcare Representative  No           122
#                            Yes            9
# Human Resources            No            40
#                            Yes           12
# Laboratory Technician      No           197
#                            Yes           62
# Manager                    No            97
#                            Yes            5
# Manufacturing Director     No           135
#                            Yes           10
# Research Director          No            78
#                            Yes            2
# Research Scientist         No           245
#                            Yes           47
# Sales Executive            No           269
#                            Yes           57
# Sales Representative       No            50
#                            Yes           33
# dtype: int64

# %% [markdown]
# This simplest possible box plot displays the full range of variation (from min age to max age),
# the likely range of variation (the IQR), and a typical value (the median) and the part where it is more concentrated.
# The data is grouped based on ‘JobRole’ so that we get a depth on which job is more
# pressurized and give them a more work life balance .

# %%
graphdata.plot.bar()

# %% [markdown]
# This  bar graph can be used to compare data among categories of ‘JobRole’  in a visual way.
