# %%
import pandas as pd

# %% [markdown]
# imprting libraries and loading datsets

# %%
data=pd.read_csv("Sapfile1.csv")

# %%
data.describe()
# Out:
#          ge  cst   tnp   twp  iap   esp  arr         ms   ls    as  ...    fq  \
# count   131  131   131   131  131   131  131        131  131   131  ...   131
# unique    2    5     4     4    4     4    2          1    2     2  ...     6
# top       M  OBC  Good  Good   Vg  Good    N  Unmarried    V  Paid  ...    Um
# freq     72   57    59    65   63    54   78        131   92    76  ...    40
#
#          mq       fo         mo     nf       sh    ss   me     tt   atd
# count   131      131        131    131      131   131  131    131   131
# unique    6        5          5      3        3     2    4      3     3
# top      Um  Service  Housewife  Large  Average  Govt  Eng  Small  Good
# freq     52       38        115     58       59    91   62     78    56
#
# [4 rows x 22 columns]

# %% [markdown]
# from the above the count on each attribute and the most frequent ones are shown

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.hist(data['ge'],bins=2)
plt.show()

import seaborn as sns
sns.set(style="darkgrid")
sns.set(style="whitegrid")
ax = sns.countplot(x="fq", data=data)
# Out:
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ...

# %%
as you see above a count plot with fathers qualification

# %%
sns.set(style="whitegrid")
ax = sns.countplot(x="atd", data=data)
# Out:
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ...

# %% [markdown]
# attendance is good for most of the students

# %%
data.head()
data.boxplot('arr',by='ge')
graphdata=data.groupby(['arr','ge']).size()

graphdata.plot.bar()
# Out:
# /srv/conda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-97c5b9d1c7b8> in <module>()
#       1 data.head()
# ----> 2 data.boxplot('arr',by='ge')
#       3 graphdata=data.groupby(['arr','ge']).size()
#       4
#       5 graphdata.plot.bar()
#
# /srv/conda/lib/python3.6/site-packages/pandas/core/frame.py in boxplot(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    5845     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    5846                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 5847                  return_type=return_type, **kwds)
# ...

# %%
# Out:
#          ge  cst   tnp   twp  iap   esp  arr         ms   ls    as  ...    fq  \
# count   131  131   131   131  131   131  131        131  131   131  ...   131
# unique    2    5     4     4    4     4    2          1    2     2  ...     6
# top       M  OBC  Good  Good   Vg  Good    N  Unmarried    V  Paid  ...    Um
# freq     72   57    59    65   63    54   78        131   92    76  ...    40
#
#          mq       fo         mo     nf       sh    ss   me     tt   atd
# count   131      131        131    131      131   131  131    131   131
# unique    6        5          5      3        3     2    4      3     3
# top      Um  Service  Housewife  Large  Average  Govt  Eng  Small  Good
# freq     52       38        115     58       59    91   62     78    56
#
# [4 rows x 22 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as p

dataset = pd.read_csv('Sapfile1.csv')
X = dataset.iloc[:, 0:24].values
y = dataset.iloc[:, 0:24].values

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 0] = labelencoder_X_1.fit_transform(X[:, 0])
labelencoder_X_2 = LabelEncoder()
X[:, 6] = labelencoder_X_2.fit_transform(X[:, 6])
onehotencoder = OneHotEncoder(categorical_features = [2])
onehotencoder1 = OneHotEncoder(categorical_features = [3])
X = onehotencoder1.fit_transform(X).toarray()
X = X[:, 6:]
X = onehotencoder.fit_transform(X).toarray()
X = X[:, 0:]


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

import keras
from keras.models import Sequential
from keras.layers import Dense


classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 24))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))


classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the traiing set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)

y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-d57f7fa8cf02> in <module>()
#      14 onehotencoder = OneHotEncoder(categorical_features = [2])
#      15 onehotencoder1 = OneHotEncoder(categorical_features = [3])
# ---> 16 X = onehotencoder1.fit_transform(X).toarray()
#      17 X = X[:, 6:]
#      18 X = onehotencoder.fit_transform(X).toarray()
#
# /srv/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# /srv/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py in _transform_selected(X, transform, selected, copy)
# ...

# %%
feature_names = ['tnp', 'twp', 'fmi', 'fs','nf','tt']
X = df2[feature_names]
# end semester percentage
y = df2['esp']
In [33]:
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
Logistic Regression
In [34]:
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(logreg.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(logreg.score(X_test, y_test)))
