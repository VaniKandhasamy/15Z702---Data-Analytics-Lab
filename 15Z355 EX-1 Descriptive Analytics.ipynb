# %%
import matplotlib.pyplot as plb
import pandas as pd
import numpy as ny
import seaborn as sns
# %matplotlib inline
d=pd.read_csv("C://Users//Hp//Desktop//EmployeeAttrition.csv")
d.head(5)

"The above function reads the data from a csv file and displays the first 5 elements from the dataframe"
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
d.describe()

"This function provides the descriptive statistics for every column in the table"
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
plb.scatter(d.TotalWorkingYears,d.YearsAtCompany,s=d.Age)

"The above scatter plot plots the total working years of an employee against the number of years he's 
worked at the company against the age attribute"

# %%
plb.scatter(d.Age,d.Attrition)
plb.show()

"A simple scatter plot, with Age plotted against Attrition"
"We can see that the 'Yes' and 'No' attributes are similar, irrespective of age"

# %%
from mpl_toolkits.mplot3d import Axes3D
threedee = plb.figure().gca(projection='3d')
threedee.scatter()
plb.show()

"A 3D plot of the total working years and the years at company"

# %%
Answer=["Yes"]

df_new=d[d['Attrition'].isin(Answer)]
df_new.head()

"Filters the employees who have chosen to leave the company ('Attrition'='Yes')"
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 0    41       Yes  Travel_Rarely       1102                   Sales
# 2    37       Yes  Travel_Rarely       1373  Research & Development
# 14   28       Yes  Travel_Rarely        103  Research & Development
# 21   36       Yes  Travel_Rarely       1218                   Sales
# 24   34       Yes  Travel_Rarely        699  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                  1          2  Life Sciences              1               1
# 2                  2          2          Other              1               4
# 14                24          3  Life Sciences              1              19
# 21                 9          4  Life Sciences              1              27
# 24                 6          1        Medical              1              31
#
#             ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
ax=d[['Age','Attrition']].plot(kind='bar')
plb.show()

"A bar graph between age and attrition"

# %%
d.boxplot(by='BusinessTravel', 
                       column=['Age'], 
                       grid=False)

"A boxplot with age against business travel"
"We can see that people who are non-travellers are mostly 35"
"People who travel frequently are around 33"
"People who travel rarely are mostly 35"

# %%
analysis=d

# %%
analysis.boxplot(by='Attrition',column=['Age'],grid=False)

"We can figure out that younger employees (with age around 30 years or less) are most likely to leave
the company"

# %%
plot = sns.boxplot(y='Age', x='Attrition', 
                 data=d, 
                 width=0.5,
                 palette="colorblind")

"A similar boxplot, but plotted using seaborn library"
