# %% [markdown]
# # Ex8 - Clustering

# %% [markdown]
# Using k-means

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
dataset = pd.read_csv('Iris.csv')
x = dataset.iloc[:, [1, 2, 3, 4]].values
kmeans = KMeans(n_clusters = 3,random_state = 0)
y_kmeans = kmeans.fit_predict(x)
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'violet', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'blue', label = 'Iris-virginica')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'red', label = 'Centroids')
plt.legend()

# %% [markdown]
# Using agglomerative clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
dataset = pd.read_csv("Iris.csv")
iris_single = dataset[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
iris_single.head()
Z = linkage(iris_single, 'ward')
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering - Single Linkage Dendrogram')
plt.xlabel('species')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp', 
    p=10,                  
    leaf_rotation=90.,      
    leaf_font_size=20.,      
)
plt.show()

# %%
Z = linkage(iris_single, 'complete')
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering - Complete Linkage Dendrogram')
plt.xlabel('species')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp', 
    p=10,                  
    leaf_rotation=90.,      
    leaf_font_size=20.,      
)
plt.show()

# %%
Z = linkage(iris_single, 'average')
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering - Average Linkage Dendrogram')
plt.xlabel('species')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp', 
    p=10,                  
    leaf_rotation=90.,      
    leaf_font_size=20.,      
)
plt.show()
