# %%
from scipy.io import arff
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = arff.loadarff('dataset.arff')
df = pd.DataFrame(data[0])

df.head()
# Out:
#      ge      cst      tnp      twp    iap      esp   arr            ms    ls  \
# 0  b'F'     b'G'  b'Good'  b'Good'  b'Vg'  b'Good'  b'Y'  b'Unmarried'  b'V'
# 1  b'M'   b'OBC'    b'Vg'    b'Vg'  b'Vg'    b'Vg'  b'N'  b'Unmarried'  b'V'
# 2  b'F'   b'OBC'  b'Good'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
# 3  b'M'  b'MOBC'  b'Pass'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
# 4  b'M'     b'G'  b'Good'  b'Good'  b'Vg'    b'Vg'  b'N'  b'Unmarried'  b'V'
#
#         as     ...         fq     mq           fo            mo          nf  \
# 0  b'Paid'     ...      b'Um'  b'10'    b'Farmer'  b'Housewife'    b'Large'
# 1  b'Paid'     ...      b'Um'  b'Il'   b'Service'    b'Service'    b'Small'
# 2  b'Paid'     ...      b'12'  b'10'   b'Service'  b'Housewife'  b'Average'
# 3  b'Paid'     ...      b'12'  b'Um'  b'Business'   b'Business'    b'Large'
# 4  b'Paid'     ...      b'10'  b'12'   b'Service'  b'Housewife'    b'Large'
#
# ...

# %%
data
# Out:
# (array([(b'F', b'G', b'Good', b'Good', b'Vg', b'Good', b'Y', b'Unmarried', b'V', b'Paid', b'Medium', b'Average', b'Um', b'10', b'Farmer', b'Housewife', b'Large', b'Poor', b'Govt', b'Asm', b'Small', b'Good'),
#         (b'M', b'OBC', b'Vg', b'Vg', b'Vg', b'Vg', b'N', b'Unmarried', b'V', b'Paid', b'Low', b'Average', b'Um', b'Il', b'Service', b'Service', b'Small', b'Poor', b'Govt', b'Asm', b'Average', b'Average'),
#         (b'F', b'OBC', b'Good', b'Good', b'Vg', b'Good', b'N', b'Unmarried', b'V', b'Paid', b'Am', b'Average', b'12', b'10', b'Service', b'Housewife', b'Average', b'Average', b'Govt', b'Asm', b'Large', b'Good'),
#         (b'M', b'MOBC', b'Pass', b'Good', b'Vg', b'Good', b'N', b'Unmarried', b'V', b'Paid', b'Medium', b'Small', b'12', b'Um', b'Business', b'Business', b'Large', b'Poor', b'Govt', b'Asm', b'Average', b'Average'),
# ...

# %% [markdown]
# # 1 . Following inferences can be made on the dataset
# ## Total count of 131 data values
# ## mostly gender specific with male having 72 frequency
# ## mostly OBCs
# ## each of them is unmarried
# ## mostly have govt jobs in Engineering

# %%
for i in df.columns:
    df[i]=df[i].str.decode('utf-8')

# %%
df.describe()
# Out:
#          ge  cst   tnp   twp  iap   esp  arr         ms   ls    as  ...    fq  \
# count   131  131   131   131  131   131  131        131  131   131  ...   131
# unique    2    5     4     4    4     4    2          1    2     2  ...     6
# top       M  OBC  Good  Good   Vg  Good    N  Unmarried    V  Paid  ...    Um
# freq     72   57    59    65   63    54   78        131   92    76  ...    40
#
#          mq       fo         mo     nf       sh    ss   me     tt   atd
# count   131      131        131    131      131   131  131    131   131
# unique    6        5          5      3        3     2    4      3     3
# top      Um  Service  Housewife  Large  Average  Govt  Eng  Small  Good
# freq     52       38        115     58       59    91   62     78    56
#
# [4 rows x 22 columns]

# %%
df.ftypes
# Out:
# ge     object:dense
# cst    object:dense
# tnp    object:dense
# twp    object:dense
# iap    object:dense
# esp    object:dense
# arr    object:dense
# ms     object:dense
# ls     object:dense
# as     object:dense
# fmi    object:dense
# fs     object:dense
# fq     object:dense
# mq     object:dense
# fo     object:dense
# mo     object:dense
# nf     object:dense
# sh     object:dense
# ss     object:dense
# me     object:dense
# tt     object:dense
# atd    object:dense
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 22 columns):
# ge     131 non-null object
# cst    131 non-null object
# tnp    131 non-null object
# twp    131 non-null object
# iap    131 non-null object
# esp    131 non-null object
# arr    131 non-null object
# ms     131 non-null object
# ls     131 non-null object
# as     131 non-null object
# fmi    131 non-null object
# fs     131 non-null object
# fq     131 non-null object
# mq     131 non-null object
# fo     131 non-null object
# mo     131 non-null object
# nf     131 non-null object
# sh     131 non-null object
# ss     131 non-null object
# me     131 non-null object
# tt     131 non-null object
# atd    131 non-null object
# dtypes: object(22)
# memory usage: 22.6+ KB
# None

# %%
df.values
# Out:
# array([['F', 'G', 'Good', ..., 'Asm', 'Small', 'Good'],
#        ['M', 'OBC', 'Vg', ..., 'Asm', 'Average', 'Average'],
#        ['F', 'OBC', 'Good', ..., 'Asm', 'Large', 'Good'],
#        ...,
#        ['F', 'OBC', 'Good', ..., 'Asm', 'Large', 'Good'],
#        ['M', 'ST', 'Pass', ..., 'Asm', 'Large', 'Average'],
#        ['M', 'G', 'Pass', ..., 'Asm', 'Small', 'Average']], dtype=object)

# %% [markdown]
# # VISUALIZATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt
carrier_count = df['ss'].value_counts()
sns.set(style="darkgrid")
sns.barplot(carrier_count.index, carrier_count.values, alpha=0.9)
plt.title('Visualization')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Jobs type', fontsize=12)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
carrier_count = df['cst'].value_counts()
sns.set(style="darkgrid")
sns.barplot(carrier_count.index, carrier_count.values, alpha=0.9)
plt.title('Visualization')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('cast', fontsize=12)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
carrier_count = df['mq'].value_counts()
sns.set(style="darkgrid")
sns.barplot(carrier_count.index, carrier_count.values, alpha=0.9)
plt.title('Visualization')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('degree', fontsize=12)
plt.show()

# %%
labels = df['ss'].astype('category').cat.categories.tolist()
counts = df['ss'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()

# %%
labels = df['cst'].astype('category').cat.categories.tolist()
counts = df['cst'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()

# %%
labels = df['mq'].astype('category').cat.categories.tolist()
counts = df['mq'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()

# %%
df['ss'].unique()
# Out:
# array(['Govt', 'Private'], dtype=object)

# %%
df['fq'].unique()
# Out:
# array(['Um', '12', '10', 'Il', 'Degree', 'Pg'], dtype=object)

# %%
df['mq'].unique()
# Out:
# array(['10', 'Il', 'Um', '12', 'Degree', 'Pg'], dtype=object)

# %%
df['ge'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['cst'].unique()
# Out:
# array(['G', 'OBC', 'MOBC', 'ST', 'SC'], dtype=object)

# %%
df['tnp'].unique()
# Out:
# array(['Good', 'Vg', 'Pass', 'Best'], dtype=object)

# %%
df['twp'].unique()
# Out:
# array(['Good', 'Vg', 'Pass', 'Best'], dtype=object)

# %% [markdown]
# # IDENTIFYING PATTERNS

# %%
df1=df.replace('Good',3)

# %%
df2=df1.replace('Vg',2)

# %%
df3=df2.replace('Pass',4)

# %%
df4=df3.replace('Best',1)

# %%
df4
# Out:
#     ge   cst  tnp  twp  iap  esp arr         ms ls    as   ...         fq  \
# 0    F     G    3    3    2    3   Y  Unmarried  V  Paid   ...         Um
# 1    M   OBC    2    2    2    2   N  Unmarried  V  Paid   ...         Um
# 2    F   OBC    3    3    2    3   N  Unmarried  V  Paid   ...         12
# 3    M  MOBC    4    3    2    3   N  Unmarried  V  Paid   ...         12
# 4    M     G    3    3    2    2   N  Unmarried  V  Paid   ...         10
# 5    M   OBC    2    3    2    2   N  Unmarried  V  Paid   ...         10
# 6    F   OBC    3    2    3    3   N  Unmarried  V  Paid   ...         12
# 7    F   OBC    3    3    3    3   N  Unmarried  V  Paid   ...         Il
# 8    F  MOBC    2    3    3    2   Y  Unmarried  V  Paid   ...         12
# 9    F   OBC    2    2    3    2   Y  Unmarried  V  Paid   ...     Degree
# 10   M    ST    2    2    3    2   N  Unmarried  V  Paid   ...         Pg
# 11   F   OBC    2    2    3    2   N  Unmarried  V  Paid   ...     Degree
# ...

# %%
df4.cov()
# Out:
#           tnp       twp       iap       esp
# tnp  0.705109  0.378802  0.268937  0.474339
# twp  0.378802  0.542689  0.212801  0.394187
# iap  0.268937  0.212801  0.480211  0.322783
# esp  0.474339  0.394187  0.322783  0.720493

# %%
df4.corr()
# Out:
#           tnp       twp       iap       esp
# tnp  1.000000  0.612363  0.462175  0.665497
# twp  0.612363  1.000000  0.416852  0.630393
# iap  0.462175  0.416852  1.000000  0.548757
# esp  0.665497  0.630393  0.548757  1.000000

# %% [markdown]
# # Identify patterns in it
# ## we see from corelation esp and tnp are most correlated columns

# %% [markdown]
# # iv)	Identify challenges if any in using the data
#
# ### The biggest challenge in using this data is lack of numerical values hence its just a categorical data

# %% [markdown]
# # v)	Get the descriptive statistics

# %% [markdown]
# ### Mean

# %%
df4['esp'].mean()
# Out:
# 2.763358778625954

# %% [markdown]
# ### Median

# %%
df4['esp'].median()
# Out:
# 3.0

# %% [markdown]
# # Prediction

# %% [markdown]
# #### Predict the end semester percentage based on various social, economic and academic attributes

# %%
le = LabelEncoder()
le.fit(df['tnp])
df['tnp'] = le.transform(df['tnp'])


trainSet, testSet = train_test_split(dataset, test_size = 0.33)
print(trainSet.shape)
print(testSet.shape)
print(trainSet.head(3))

# %%
trainData = pd.DataFrame.as_matrix(trainSet[['cst', 'esc', 'tmp', 'tnp']])
trainTarget = pd.DataFrame.as_matrix(trainSet[['tmp']]).ravel()
testData = pd.DataFrame.as_matrix(testSet[['cst', 'esc', 'tmp', 'tnp']])
testTarget = pd.DataFrame.as_matrix(testSet[['esc']]).ravel()

classifier = GaussianNB()
classifier.fit(trainData, trainTarget)

# %%
predictedValues = classifier.predict(testData)

nErrors = (testTarget != predictedValues).sum()
accuracy = 1.0 - nErrors / testTarget.shape[0]
print("Accuracy: ", accuracy)
