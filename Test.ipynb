# %%
from scipy.io import arff
import pandas as pd
import seaborn as sns

# %%
data = arff.loadarff('C:\\Users\\cse49\\Desktop\\a.arff')
df = pd.DataFrame(data[0])
df.to_csv('C:\\Users\\cse49\\Desktop\\a1.csv')

# %%
df = pd.read_csv('C:\\Users\\cse49\\Desktop\\s1.csv',encoding="utf-8")

# %%
df
# Out:
#     ge   cst   tnp   twp   iap   esp arr         ms ls    as   ...         fq  \
# 0    F     G  Good  Good    Vg  Good   Y  Unmarried  V  Paid   ...         Um
# 1    M   OBC    Vg    Vg    Vg    Vg   N  Unmarried  V  Paid   ...         Um
# 2    F   OBC  Good  Good    Vg  Good   N  Unmarried  V  Paid   ...         12
# 3    M  MOBC  Pass  Good    Vg  Good   N  Unmarried  V  Paid   ...         12
# 4    M     G  Good  Good    Vg    Vg   N  Unmarried  V  Paid   ...         10
# 5    M   OBC    Vg  Good    Vg    Vg   N  Unmarried  V  Paid   ...         10
# 6    F   OBC  Good    Vg  Good  Good   N  Unmarried  V  Paid   ...         12
# 7    F   OBC  Good  Good  Good  Good   N  Unmarried  V  Paid   ...         Il
# 8    F  MOBC    Vg  Good  Good    Vg   Y  Unmarried  V  Paid   ...         12
# 9    F   OBC    Vg    Vg  Good    Vg   Y  Unmarried  V  Paid   ...     Degree
# 10   M    ST    Vg    Vg  Good    Vg   N  Unmarried  V  Paid   ...         Pg
# ...

# %%
count_row = df.shape[0]  # gives number of row count
count_col = df.shape[1]  # gives number of column count 
df.dtypes #lists down the data types of objects

# %%
count_row
# Out:
# 131

# %%
count_col
# Out:
# 22

# %%
df.dtypes
# Out:
# ge     object
# cst    object
# tnp    object
# twp    object
# iap    object
# esp    object
# arr    object
# ms     object
# ls     object
# as     object
# fmi    object
# fs     object
# fq     object
# mq     object
# fo     object
# mo     object
# nf     object
# sh     object
# ss     object
# me     object
# tt     object
# atd    object
# dtype: object

# %%
# Out:
# 0      F
# 1      M
# 2      F
# 3      M
# 4      M
# 5      M
# 6      F
# 7      F
# 8      F
# 9      F
# 10     M
# 11     F
# 12     M
# 13     M
# 14     F
# 15     F
# 16     F
# 17     M
# 18     M
# 19     M
# 20     F
# 21     F
# 22     F
# 23     F
# 24     F
# 25     F
# 26     F
# 27     F
# 28     M
# 29     F
#       ..
# 101    M
# 102    M
# 103    M
# 104    M
# 105    M
# 106    M
# 107    M
# 108    F
# 109    M
# 110    M
# 111    M
# 112    M
# 113    F
# 114    F
# 115    F
# 116    M
# 117    M
# 118    M
# 119    M
# 120    F
# 121    M
# 122    M
# 123    M
# 124    M
# 125    M
# 126    M
# 127    M
# 128    F
# 129    M
# 130    M
# Name: ge, Length: 131, dtype: object

# %%
import matplotlib.pyplot as plt
plt.scatter(df['ge'], df['atd'], marker='o');

# %%
plt.scatter(df['ge'], df['atd'], marker='o');

# %%
df.describe() #descriptive statistics
# Out:
#          ge  cst   tnp   twp  iap   esp  arr         ms   ls    as  ...    fq  \
# count   131  131   131   131  131   131  131        131  131   131  ...   131
# unique    2    5     4     4    4     4    2          1    2     2  ...     6
# top       M  OBC  Good  Good   Vg  Good    N  Unmarried    V  Paid  ...    Um
# freq     72   57    59    65   63    54   78        131   92    76  ...    40
#
#          mq       fo         mo     nf       sh    ss   me     tt   atd
# count   131      131        131    131      131   131  131    131   131
# unique    6        5          5      3        3     2    4      3     3
# top      Um  Service  Housewife  Large  Average  Govt  Eng  Small  Good
# freq     52       38        115     58       59    91   62     78    56
#
# [4 rows x 22 columns]

# %%
m_c = int(df[df['ge'] == 'M'].shape[0])
m_f = int(df[df['ge'] == 'F'].shape[0])
a = ['M','F']
b = [m_c,m_f] 
plt.pie(b, labels=a, startangle=90, autopct='%.1f%%')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
# Out:
# C:\Users\cse49\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn import preprocessing 
df = df.apply(preprocessing.LabelEncoder().fit_transform)
X = df[['ge','tnp','twp','cst','esp','mo','nf']]
Y = df[['atd']]

# %%
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.3, random_state = 100)

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,
                               max_depth=3, min_samples_leaf=5)
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best')

# %%
y_pred = clf_gini.predict(X_test)

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 47.5

# %%
df
# Out:
#      ge  cst  tnp  twp  iap  esp  arr  ms  ls  as ...   fq  mq  fo  mo  nf  \
# 0     0    0    1    1    3    1    1   0   1   1 ...    5   0   1   1   1
# 1     1    2    3    3    3    3    0   0   1   1 ...    5   3   4   4   2
# 2     0    2    1    1    3    1    0   0   1   1 ...    1   0   4   1   0
# 3     1    1    2    1    3    1    0   0   1   1 ...    1   5   0   0   1
# 4     1    0    1    1    3    3    0   0   1   1 ...    0   1   4   1   1
# 5     1    2    3    1    3    3    0   0   1   1 ...    0   5   1   1   2
# 6     0    2    1    3    1    1    0   0   1   1 ...    1   2   4   4   0
# 7     0    2    1    1    1    1    0   0   1   1 ...    3   5   1   1   2
# 8     0    1    3    1    1    3    1   0   1   1 ...    1   0   2   1   2
# 9     0    2    3    3    1    3    1   0   1   1 ...    2   2   2   1   1
# 10    1    4    3    3    1    3    0   0   1   1 ...    4   4   3   3   1
# ...

# %%
m_c = int(df[df['tnp'] == 1].shape[0])
m_f = int(df[df['tnp'] == 3].shape[0])
m_d = int(df[df['tnp'] == 2].shape[0])

# %%
a = ['Good','Pass','Very Good']
b = [m_c,m_f,m_d] 
plt.pie(b, labels=a, startangle=90, autopct='%.1f%%')
plt.show()

# %%
plt.barh(a, b, align='center', alpha=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
df.sum()
# Out:
# ge      72
# cst    212
# tnp    223
# twp    231
# iap    256
# esp    234
# arr     53
# ms       0
# ls      92
# as      76
# fmi    268
# fs     180
# fq     346
# mq     384
# fo     246
# mo     170
# nf     118
# sh     117
# ss      40
# me     147
# tt     166
# atd    112
# dtype: int64

# %%
m_c = int(df[df['atd'] == 1].shape[0])
m_f = int(df[df['atd'] == 0].shape[0])
m_d = int(df[df['atd'] == 2].shape[0])

# %%
a = ['Good','Poor','Medium']
b = [m_c,m_f,m_d] 
plt.pie(b, labels=a, startangle=90, autopct='%.1f%%')
plt.show()

# %%
plt.barh(a, b, align='center', alpha=0.5)
# Out:
# <BarContainer object of 3 artists>
