# %%
import pandas as pd
df1 = pd.read_csv("D:/Studies/MovieGenre.csv",encoding='latin-1')
df2=df1['Genre']
s = set();
for var in range(2,300):
    l1=df2[var].split("|");
    for var1 in l1:
        s.add(var1);

import os;
os.chdir("D:/Studies/Result/")

for var in s:
    os.mkdir(var);

df2=df1['Poster']
df3=df1['Genre']

import urllib.request
v="D:/Studies/Result/";
for var in range(2,300):
    l1=df3[var].split("|");
    for var1 in l1:
        v1=v+str(var1)+"/"+str(var)+".jpg";
        print(v1)
        try:
            print(df2[var]);
            urllib.request.urlretrieve(df2[var],v1)
        except:
            pass;
# Out:
# D:/Studies/Result/Comedy/2.jpg
# https://images-na.ssl-images-amazon.com/images/M/MV5BMjQxM2YyNjMtZjUxYy00OGYyLTg0MmQtNGE2YzNjYmUyZTY1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX182_CR0,0,182,268_AL_.jpg
# D:/Studies/Result/Romance/2.jpg
# https://images-na.ssl-images-amazon.com/images/M/MV5BMjQxM2YyNjMtZjUxYy00OGYyLTg0MmQtNGE2YzNjYmUyZTY1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX182_CR0,0,182,268_AL_.jpg
# D:/Studies/Result/Comedy/3.jpg
# https://images-na.ssl-images-amazon.com/images/M/MV5BMTczMTMyMTgyM15BMl5BanBnXkFtZTcwOTc4OTQyMQ@@._V1_UY268_CR4,0,182,268_AL_.jpg
# D:/Studies/Result/Drama/3.jpg
# https://images-na.ssl-images-amazon.com/images/M/MV5BMTczMTMyMTgyM15BMl5BanBnXkFtZTcwOTc4OTQyMQ@@._V1_UY268_CR4,0,182,268_AL_.jpg
# D:/Studies/Result/Romance/3.jpg
# https://images-na.ssl-images-amazon.com/images/M/MV5BMTczMTMyMTgyM15BMl5BanBnXkFtZTcwOTc4OTQyMQ@@._V1_UY268_CR4,0,182,268_AL_.jpg
# D:/Studies/Result/Comedy/4.jpg
# ...
