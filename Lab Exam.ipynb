# %%
import pandas as pd
data = pd.read_csv("Sapfile1.csv")
print(data)
# Out:
#     ge   cst   tnp   twp   iap   esp arr         ms ls    as   ...        mq  \
# 0    F     G  Good  Good    Vg  Good   Y  Unmarried  V  Paid   ...        10
# 1    M   OBC    Vg    Vg    Vg    Vg   N  Unmarried  V  Paid   ...        Il
# 2    F   OBC  Good  Good    Vg  Good   N  Unmarried  V  Paid   ...        10
# 3    M  MOBC  Pass  Good    Vg  Good   N  Unmarried  V  Paid   ...        Um
# 4    M     G  Good  Good    Vg    Vg   N  Unmarried  V  Paid   ...        12
# 5    M   OBC    Vg  Good    Vg    Vg   N  Unmarried  V  Paid   ...        Um
# 6    F   OBC  Good    Vg  Good  Good   N  Unmarried  V  Paid   ...    Degree
# 7    F   OBC  Good  Good  Good  Good   N  Unmarried  V  Paid   ...        Um
# 8    F  MOBC    Vg  Good  Good    Vg   Y  Unmarried  V  Paid   ...        10
# 9    F   OBC    Vg    Vg  Good    Vg   Y  Unmarried  V  Paid   ...    Degree
# 10   M    ST    Vg    Vg  Good    Vg   N  Unmarried  V  Paid   ...        Pg
# ...

# %%
data.describe()
# Out:
#           F    G  Good Good.1   Vg Good.2    Y  Unmarried    V  Paid  ...    \
# count   130  130   130    130  130    130  130        130  130   130  ...
# unique    2    5     4      4    4      4    2          1    2     2  ...
# top       M  OBC  Good   Good   Vg   Good    N  Unmarried    V  Paid  ...
# freq     72   57    58     64   62     53   78        130   91    75  ...
#
#          Um   10   Farmer  Housewife  Large     Poor  Govt  Asm  Small Good.3
# count   130  130      130        130    130      130   130  130    130    130
# unique    6    6        5          5      3        3     2    4      3      3
# top      Um   Um  Service  Housewife  Large  Average  Govt  Eng  Small   Good
# freq     39   52       38        114     57       59    90   62     77     55
#
# [4 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
fig=plt.figure() 
ax = fig.add_subplot(1,1,1)
ax.hist(data['mq'])
plt.show()

# %% [markdown]
# The above plot shows the histogram of the attribute 'mq' i.e., mother's qualification

# %%
import seaborn as sns
sns.set(style="whitegrid")
ax = sns.countplot(x="fq", data=data)

# %% [markdown]
# As we can see from the above plot, the number of people, whose father's qualification is undergradution, is high

# %%
sns.set(style="darkgrid")
a=sns.countplot(x='atd',hue="tnp",data=data)

# %% [markdown]
# As we can see from the above plot, people who have good attendance have performed well in the tnp

# %%
data['esp'].unique()
data['tnp'].unique()
data['twp'].unique()
data['iap'].unique()
data=data.replace('Good',2)
data=data.replace('Vg',3)
data=data.replace('Pass',1)
data=data.replace('Best',4)
y_val = data[['esp']]

x_val = data[['tnp','twp','iap']]



from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_val,y_val, test_size= 0.40, random_state=25)

from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

g = GaussianNB()

bayes_model = g.fit(x_train, y_train)

y_pred = bayes_model.predict(x_test)

print("The accuracy is : "+str(round(accuracy_score(y_test, y_pred),4)))

confusion = confusion_matrix(y_test,y_pred)
print("The confusion matrix is: ")
print(confusion)
# Out:
# The accuracy is : 0.6415
# The confusion matrix is:
# [[14  4  9]
#  [ 5 10  0]
#  [ 1  0 10]]
# C:\ana1\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# The above code snippet tries to build the Bayesian Model for classifying
