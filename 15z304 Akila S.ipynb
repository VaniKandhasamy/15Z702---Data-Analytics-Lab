# %%
import pandas as pd
#Importing the dataset
df = pd.read_csv("C:\Users\cse41\Downloads\as.csv")
print(df)
# Out:
#   File "<ipython-input-4-95ae125b5f2e>", line 3
#     df = pd.read_csv("C:\Users\cse41\Downloads\as.csv")
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
#Importing the dataset
df = pd.read_csv('C:\Users\cse41\Downloads\as.csv')
print(df)
# Out:
#   File "<ipython-input-5-9c708d291ecd>", line 3
#     df = pd.read_csv('C:\Users\cse41\Downloads\as.csv')
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
  
import pandas as pd
#Importing the dataset
df = pd.read_csv('EmployeeAttrition.csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-c3a4c439c9cb> in <module>()
#       2 import pandas as pd
#       3 #Importing the dataset
# ----> 4 df = pd.read_csv('EmployeeAttrition.csv')
#       5 print(df)
#       6
#
# ...

# %%
import pandas as pd
#Importing the dataset
df = pd.read_csv("as.csv")
print(df)
# Out:
#   File "<ipython-input-7-95ae125b5f2e>", line 3
#     df = pd.read_csv("C:\Users\cse41\Downloads\as.csv")
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
#Importing the dataset
df = pd.read_csv("as.csv")
print(df)
# Out:
#                                                     ge   cst   tnp   twp  \
# 0                                                    F     G  Good  Good
# 1                                                    M   OBC    Vg    Vg
# 2                                                    F   OBC  Good  Good
# 3                                                    M  MOBC  Pass  Good
# 4                                                    M     G  Good  Good
# 5                                                    M   OBC    Vg  Good
# 6                                                    F   OBC  Good    Vg
# 7                                                    F   OBC  Good  Good
# 8                                                    F  MOBC    Vg  Good
# 9                                                    F   OBC    Vg    Vg
# 10                                                   M    ST    Vg    Vg
# 11                                                   F   OBC    Vg    Vg
# ...

# %%
df.describe()
# Out:
#          ge  cst   tnp   twp  iap   esp arrr         ms   ls    as  ...    fq  \
# count   132  131   131   131  131   131  131        131  131   131  ...   131
# unique    3    5     4     4    4     4    2          1    2     2  ...     6
# top       M  OBC  Good  Good   Vg  Good    N  Unmarried    V  Paid  ...    Um
# freq     72   57    59    65   63    54   78        131   92    76  ...    40
#
#          mq       fo         mo     nf       sh    ss   me     tt   atd
# count   131      131        131    131      131   131  131    131   131
# unique    6        5          5      3        3     2    4      3     3
# top      Um  Service  Housewife  Large  Average  Govt  Eng  Small  Good
# freq     52       38        115     58       59    91   62     78    56
#
# [4 rows x 22 columns]

# %%
print(len(df))
# Out:
# 132

# %%
df.isnull().sum()
# Out:
# ge      0
# cst     1
# tnp     1
# twp     1
# iap     1
# esp     1
# arrr    1
# ms      1
# ls      1
# as      1
# fmi     1
# fs      1
# fq      1
# mq      1
# fo      1
# mo      1
# nf      1
# sh      1
# ss      1
# me      1
# tt      1
# atd     1
# dtype: int64

# %%
import matplotlib.pyplot as plt
df.boxplot('arr')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-5318ae2d1c00> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 df.boxplot('arr')
#
# /srv/conda/lib/python3.6/site-packages/pandas/core/frame.py in boxplot(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    5845     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    5846                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 5847                  return_type=return_type, **kwds)
#    5848     plt.draw_if_interactive()
#    5849     return ax
#
# /srv/conda/lib/python3.6/site-packages/pandas/plotting/_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2016             columns = data.columns
#    2017         else:
# -> 2018             data = data[columns]
#    2019
# ...

# %%
import matplotlib.pyplot as plt
df = pd.DataFrame(np.random.randn(10,4),columns=['Col1', 'Col2', 'Col3', 'Col4'])
 boxplot = df.boxplot(column=['Col1', 'Col2', 'Col3'])
# Out:
#   File "<ipython-input-14-7641c64ac4b3>", line 3
#     boxplot = df.boxplot(column=['Col1', 'Col2', 'Col3'])
#     ^
# IndentationError: unexpected indent

# %%
import matplotlib.pyplot as plt
import pandas as pd
fig=plt.figure()
ax = fig.add_subplot(1,1,1)
#Variable
ax.boxplot(df['arr'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'arr'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df.boxplot(column="as",by="ls")
# Out:
# /srv/conda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-706827beaa66> in <module>()
# ----> 1 df.boxplot(column="as",by="ls")
#
# /srv/conda/lib/python3.6/site-packages/pandas/core/frame.py in boxplot(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    5845     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    5846                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 5847                  return_type=return_type, **kwds)
#    5848     plt.draw_if_interactive()
#    5849     return ax
#
# ...

# %%
df['mp'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'mp'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st
from scipy.io import arff
from io import StringIO
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = arff.loadarff('as.csv')
df=pd.DataFrame(data[0])
df.head()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-20-f9257baa519c> in <module>()
#      10 import seaborn as sns
#      11 import matplotlib.pyplot as plt
# ---> 12 data = arff.loadarff('as.csv')
#      13 df=pd.DataFrame(data[0])
#      14 df.head()
#
# /srv/conda/lib/python3.6/site-packages/scipy/io/arff/arffread.py in loadarff(f)
#     539         ofile = open(f, 'rt')
#     540     try:
# --> 541         return _loadarff(ofile)
#     542     finally:
#     543         if ofile is not f:  # only close what we opened
#
# /srv/conda/lib/python3.6/site-packages/scipy/io/arff/arffread.py in _loadarff(ofile)
#     548     # Parse the header file
#     549     try:
# --> 550         rel, attr = read_header(ofile)
#     551     except ValueError as e:
#     552         msg = "Error while parsing header, error was: " + str(e)
#
# ...

# %%
df.mean()
# Out:
# Series([], dtype: float64)

# %%
df.median()
# Out:
# Series([], dtype: float64)

# %%
df.mode()
# Out:
#   ge  cst   tnp   twp iap   esp arrr         ms ls    as  ...   fq  mq  \
# 0  M  OBC  Good  Good  Vg  Good    N  Unmarried  V  Paid  ...   Um  Um
#
#         fo         mo     nf       sh    ss   me     tt   atd
# 0  Service  Housewife  Large  Average  Govt  Eng  Small  Good
#
# [1 rows x 22 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#breakdown by class
sns.countplot(x="fo", data=df, palette="muted");
plt.show()


df['Fail'] = np.where(df['tnp']=='best',1,0)
sns.factorplot('tnp','Fail',data=df,size=5)
# Out:
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ...

# %%
pd.crosstab(df['sh'],df['atd'])
# Out:
# atd      Average  Good  Poor
# sh
# Average       18    27    14
# Good           9    15     3
# Poor          20    14    11

# %%
pd.crosstab(df['sh'],df['arr'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'arr'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df.tt.value_counts()
# Out:
# Small      78
# Average    43
# Large      10
# Name: tt, dtype: int64
