# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from pandas import read_csv

# %%
df = pd.read_csv('Z:/dataset.csv')

# %%
df.describe(include = "all")
# Out:
#          ge  cst   tnp   twp  iap   esp  arr         ms   ls    as  ...    fq  \
# count   131  131   131   131  131   131  131        131  131   131  ...   131
# unique    2    5     4     4    4     4    2          1    2     2  ...     6
# top       M  OBC  Good  Good   Vg  Good    N  Unmarried    V  Paid  ...    Um
# freq     72   57    59    65   63    54   78        131   92    76  ...    40
#
#          mq       fo         mo     nf       sh    ss   me     tt   atd
# count   131      131        131    131      131   131  131    131   131
# unique    6        5          5      3        3     2    4      3     3
# top      Um  Service  Housewife  Large  Average  Govt  Eng  Small  Good
# freq     52       38        115     58       59    91   62     78    56
#
# [4 rows x 22 columns]

# %%
print(df)
# Out:
#     ge   cst   tnp   twp   iap   esp arr         ms ls    as   ...         fq  \
# 0    F     G  Good  Good    Vg  Good   Y  Unmarried  V  Paid   ...         Um
# 1    M   OBC    Vg    Vg    Vg    Vg   N  Unmarried  V  Paid   ...         Um
# 2    F   OBC  Good  Good    Vg  Good   N  Unmarried  V  Paid   ...         12
# 3    M  MOBC  Pass  Good    Vg  Good   N  Unmarried  V  Paid   ...         12
# 4    M     G  Good  Good    Vg    Vg   N  Unmarried  V  Paid   ...         10
# 5    M   OBC    Vg  Good    Vg    Vg   N  Unmarried  V  Paid   ...         10
# 6    F   OBC  Good    Vg  Good  Good   N  Unmarried  V  Paid   ...         12
# 7    F   OBC  Good  Good  Good  Good   N  Unmarried  V  Paid   ...         Il
# 8    F  MOBC    Vg  Good  Good    Vg   Y  Unmarried  V  Paid   ...         12
# 9    F   OBC    Vg    Vg  Good    Vg   Y  Unmarried  V  Paid   ...     Degree
# 10   M    ST    Vg    Vg  Good    Vg   N  Unmarried  V  Paid   ...         Pg
# ...

# %%
df.dtypes
# Out:
# ge     object
# cst    object
# tnp    object
# twp    object
# iap    object
# esp    object
# arr    object
# ms     object
# ls     object
# as     object
# fmi    object
# fs     object
# fq     object
# mq     object
# fo     object
# mo     object
# nf     object
# sh     object
# ss     object
# me     object
# tt     object
# atd    object
# dtype: object

# %%
df.head()
# Out:
#   ge   cst   tnp   twp iap   esp arr         ms ls    as   ...     fq  mq  \
# 0  F     G  Good  Good  Vg  Good   Y  Unmarried  V  Paid   ...     Um  10
# 1  M   OBC    Vg    Vg  Vg    Vg   N  Unmarried  V  Paid   ...     Um  Il
# 2  F   OBC  Good  Good  Vg  Good   N  Unmarried  V  Paid   ...     12  10
# 3  M  MOBC  Pass  Good  Vg  Good   N  Unmarried  V  Paid   ...     12  Um
# 4  M     G  Good  Good  Vg    Vg   N  Unmarried  V  Paid   ...     10  12
#
#          fo         mo       nf       sh       ss   me       tt      atd
# 0    Farmer  Housewife    Large     Poor     Govt  Asm    Small     Good
# 1   Service    Service    Small     Poor     Govt  Asm  Average  Average
# 2   Service  Housewife  Average  Average     Govt  Asm    Large     Good
# 3  Business   Business    Large     Poor     Govt  Asm  Average  Average
# 4   Service  Housewife    Large     Poor  Private  Asm    Small     Good
#
# [5 rows x 22 columns]

# %%
df.cumsum()
# Out:
#                                                     ge  \
# 0                                                    F
# 1                                                   FM
# 2                                                  FMF
# 3                                                 FMFM
# 4                                                FMFMM
# 5                                               FMFMMM
# 6                                              FMFMMMF
# 7                                             FMFMMMFF
# 8                                            FMFMMMFFF
# 9                                           FMFMMMFFFF
# 10                                         FMFMMMFFFFM
# 11                                        FMFMMMFFFFMF
# 12                                       FMFMMMFFFFMFM
# 13                                      FMFMMMFFFFMFMM
# 14                                     FMFMMMFFFFMFMMF
# 15                                    FMFMMMFFFFMFMMFF
# ...

# %%
df.count()
# Out:
# ge     131
# cst    131
# tnp    131
# twp    131
# iap    131
# esp    131
# arr    131
# ms     131
# ls     131
# as     131
# fmi    131
# fs     131
# fq     131
# mq     131
# fo     131
# mo     131
# nf     131
# sh     131
# ss     131
# me     131
# tt     131
# atd    131
# dtype: int64

# %%
df.mean()
# Out:
# Series([], dtype: float64)

# %%
df.median()
# Out:
# Series([], dtype: float64)

# %%
df.mode()
# Out:
#   ge  cst   tnp   twp iap   esp arr         ms ls    as  ...   fq  mq  \
# 0  M  OBC  Good  Good  Vg  Good   N  Unmarried  V  Paid  ...   Um  Um
#
#         fo         mo     nf       sh    ss   me     tt   atd
# 0  Service  Housewife  Large  Average  Govt  Eng  Small  Good
#
# [1 rows x 22 columns]

# %%
df.ge.plot(kind = "bar")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-6305eb7fa955> in <module>()
# ----> 1 df.ge.plot(kind = "bar")
#
# AttributeError: 'function' object has no attribute 'plot'

# %%
df.isnull()
# Out:
#         ge    cst    tnp    twp    iap    esp    arr     ms     ls     as  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# 5    False  False  False  False  False  False  False  False  False  False
# 6    False  False  False  False  False  False  False  False  False  False
# 7    False  False  False  False  False  False  False  False  False  False
# 8    False  False  False  False  False  False  False  False  False  False
# 9    False  False  False  False  False  False  False  False  False  False
# 10   False  False  False  False  False  False  False  False  False  False
# 11   False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.interpolate()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-11c47216a02d> in <module>()
# ----> 1 df.interpolate()
#
# C:\ProgramData\Ana\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6009         if _maybe_transposed_self._data.get_dtype_counts().get(
#    6010                 'object') == len(_maybe_transposed_self.T):
# -> 6011             raise TypeError("Cannot interpolate with all NaNs.")
#    6012
#    6013         # create/use the index
#
# TypeError: Cannot interpolate with all NaNs.

# %%
df.std()
# Out:
# Series([], dtype: float64)

# %%
df.groupby('ge')

# %%
df.groupby('cst')

# %%
df.area()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-4e0ffcdaf79b> in <module>()
# ----> 1 df.area()
#
# C:\ProgramData\Ana\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'area'

# %%
plt.style.use('ggplot')

# %%
df = pd.crosstab(df['ge'], df['cst'])

# %%
print (df)
# Out:
# cst   G  MOBC  OBC  SC  ST
# ge
# F    18     2   29   3   7
# M    26     4   28   1  13

# %%
df.plot.bar()

# %%
df = pd.read_csv('Z:/dataset.csv')

# %%
df = pd.crosstab(df['as'], df['mo'])

# %%
print(df)
# Out:
# mo    Business  Housewife  Others  Retired  Service
# as
# Free         0         48       1        0        6
# Paid         1         67       1        1        6

# %%
df.plot.hist()

# %%
df.plot.box()

# %%
df = pd.read_csv('Z:/dataset.csv')

# %%
df = pd.crosstab(df['ge'], df['fo'])

# %%
print(df)
# Out:
# fo  Business  Farmer  Others  Retired  Service
# ge
# F         22       6      12        1       18
# M         12      21      17        2       20

# %%
df.plot.area()
