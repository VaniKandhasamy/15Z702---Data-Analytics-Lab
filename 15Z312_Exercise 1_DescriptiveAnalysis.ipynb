# %% [markdown]
# # Exercise 1
# # Descriptive Analysis

# %% [markdown]
# ## <b>Problem Description</b>
# To perform descriptive analysis on Employee Attrition database

# %% [markdown]
# ### Step 1
#
# Import the required packages<br>
# We will using numpy and pandas to store the data values and matplotlib to plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2
#
# Import the data file into a data frame<br>

# %%
dataFrame = pd.read_csv('CSV//EmployeeAttrition.csv')
dataFrame.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
dataFrame.shape
# Out:
# (1470, 35)

# %%
dataFrame.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### Step 3

# %%
dataFrame.boxplot('DailyRate',by='Attrition')

# %%
dataFrame.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
plt.scatter(dataFrame.TotalWorkingYears,dataFrame.JobLevel,s=dataFrame.Age)

# %%
dataFrame.Age
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
# 5       32
# 6       59
# 7       30
# 8       38
# 9       36
# 10      35
# 11      29
# 12      31
# 13      34
# 14      28
# 15      29
# 16      32
# 17      22
# 18      53
# 19      38
# 20      24
# 21      36
# 22      34
# 23      21
# 24      34
# 25      53
# 26      32
# 27      42
# 28      44
# 29      46
#         ..
# 1440    36
# 1441    56
# 1442    29
# 1443    42
# 1444    56
# 1445    41
# 1446    34
# 1447    36
# 1448    41
# 1449    32
# 1450    35
# 1451    38
# 1452    50
# 1453    36
# 1454    45
# 1455    40
# 1456    35
# 1457    40
# 1458    35
# 1459    29
# 1460    29
# 1461    50
# 1462    39
# 1463    31
# 1464    26
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %%
plt.scatter(dataFrame.DistanceFromHome,dataFrame.JobLevel)
